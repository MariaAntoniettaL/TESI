# %% [markdown]
# Qui provo a vedere se posso aggiungere al validation originale (nelle features ci sono valori non per forza numerici) una feature booleana che dice se la predizione è giusta o sbagliata

# %%
from preprocessing_for_adult import preprocessing_funct_not_enc, encoding_funct
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
import torch

# %%
torch.manual_seed(42)

# %%
col_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
                'marital-status', 'occupation', 'relationship', 'race', 'sex',
                'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
df = pd.read_csv("adult.data", header = None, names = col_names)

# %%
null_count = df.isnull().sum()
print(null_count)
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df_train, df_val, df_test, df_holdout = preprocessing_funct_not_enc(df)
#controllo divisione dataset
print(f"TRAIN SET ROWS: ", df_train.shape[0]) #su 32536, il 40%  dovrebbe essere circa 13014
print(f"VALIDATION SET ROWS: ", df_val.shape[0]) #su 32536, il 20%  dovrebbe essere circa 6500
print(f"HOLDOUT SET ROWS: ", df_holdout.shape[0])
print(f"TEST SET ROWS: ", df_test.shape[0])
# Out:
# TRAIN SET ROWS:  13014
# VALIDATION SET ROWS:  6507
# HOLDOUT SET ROWS:  6508
# TEST SET ROWS:  6508

# %%
df_train_enc, df_test_enc, df_holdout_enc, df_val_enc = encoding_funct(df_train=df_train, df_test=df_test, df_holdout=df_holdout, df_val=df_val)
#controllo divisione dataset
print(f"TRAIN SET ROWS: ", df_train_enc.shape[0]) #su 32536, il 40%  dovrebbe essere circa 13014
print(f"VALIDATION SET ROWS: ", df_val_enc.shape[0]) #su 32536, il 20%  dovrebbe essere circa 6500
print(f"HOLDOUT SET ROWS: ", df_holdout_enc.shape[0])
print(f"TEST SET ROWS: ", df_test_enc.shape[0])
# Out:
# TRAIN SET ROWS:  13014
# VALIDATION SET ROWS:  6507
# HOLDOUT SET ROWS:  6508
# TEST SET ROWS:  6508

# %%
df_train_no_income = df_train_enc.drop(columns = 'income')
plt.figure(figsize=(4, 3))
g = sns.heatmap(df_train_no_income.corr(),
                annot = False,
                cmap = "coolwarm")

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
X_train = df_train_enc.drop(columns = 'income', axis = 1)
y_train = df_train_enc['income']

X_test = df_test_enc.drop(columns = 'income', axis = 1)
y_test = df_test_enc['income']

X_val = df_val_enc.drop(columns = 'income', axis = 1)
y_val = df_val_enc['income']

X_holdout = df_holdout_enc.drop(columns = 'income', axis = 1)
y_holdout = df_holdout_enc['income']

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
cm_dt = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=[False, True])
disp.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      4940
#            1       0.59      0.61      0.60      1568
#
#     accuracy                           0.81      6508
#    macro avg       0.73      0.74      0.74      6508
# weighted avg       0.81      0.81      0.81      6508

# %%
tn, fp, fn, tp = cm_dt.ravel()

accuracy = accuracy_score(y_test, y_pred)
false_positive_rate = fp / (fp + tn)
false_negative_rate = fn / (fn + tp)

metrics_df = pd.DataFrame({
    'Accuracy': [accuracy],
    'False Positive Rate': [false_positive_rate],
    'False Negative Rate': [false_negative_rate],
    'False Positives': [fp],
    'False Negatives': [fn]
})

#prima della ricerca dei sottogruppi 
metrics_df
# Out:
#    Accuracy  False Positive Rate  False Negative Rate  False Positives  \
# 0  0.805624             0.131377             0.392857              649
#
#    False Negatives
# 0              616

# %% [markdown]
# SUBGROUPS SEARCH
#
# -Identifico i gruppi applicando DivExplorer sul validation not encoded (a cui ho aggiunto la feature sui falsi positivi da passare a boolean outcomes)
#
# -Integro nel training set dati che matchano sottogruppi problematici prendendoli dall'holdout
#
# -Ripetro training e test

# %%
from divexplorer import DivergenceExplorer
from divexplorer import DivergencePatternProcessor
from divexplorer.outcomes import get_false_positive_rate_outcome

# %%
#predizioni per il validation set
y_pred_val_dt = dt.predict(X_val)

df_val_dt = X_val.copy()
df_val_dt['y_val_true'] = y_val
df_val_dt['y_pred'] = y_pred_val_dt

df_val_dt.head()
# Out:
#        workclass    fnlwgt  education  marital-status  occupation  \
# 18761          2  0.077282          3               0           4
# 27582          3  0.047901          3               1           4
# 30911          2  0.174473          3               3           4
# 11128          0  0.011908          2               1           2
# 683            0  0.284255          3               3           2
#
#        relationship  race  sex  capital-gain  capital-loss  native-country  \
# 18761             1     4    0       0.00000      0.000000               0
# 27582             0     4    1       0.00000      0.000000               0
# 30911             4     2    0       0.03887      0.000000               0
# 11128             0     2    1       0.00000      0.506923               0
# 683               4     2    1       0.00000      0.000000               0
#
#        age_group  edu_num_group  hours_per_week_group  y_val_true  y_pred
# 18761          2              1                     1           0       0
# 27582          5              1                     2           1       0
# 30911          1              1                     1           0       0
# 11128          3              4                     1           1       1
# 683            0              1                     1           0       0

# %%
y_trues = df_val_dt["y_val_true"]
y_preds = df_val_dt["y_pred"]

df_val_dt['fp'] =  get_false_positive_rate_outcome(y_trues, y_preds)

#aggiungo la feature 'fp' a df_val
df_val['fp'] = df_val_dt['fp']
df_val.head()
# Out:
#         workclass    fnlwgt        education marital-status    occupation  \
# 18761     Private  0.077282    Non Graduated       Divorced  Self-emp-occ
# 27582    Self-emp  0.047901    Non Graduated        Married  Self-emp-occ
# 30911     Private  0.174473    Non Graduated      Separated  Self-emp-occ
# 11128  Government  0.011908  Master's Degree        Married   Private-occ
# 683    Government  0.284255    Non Graduated      Separated   Private-occ
#
#          relationship    race      sex  capital-gain  capital-loss  \
# 18761   Not-in-family   White   Female       0.00000      0.000000
# 27582         Husband   White     Male       0.00000      0.000000
# 30911       Unmarried   Black   Female       0.03887      0.000000
# 11128         Husband   Black     Male       0.00000      0.506923
# 683         Unmarried   Black     Male       0.00000      0.000000
#
#                 native-country  income age_group       edu_num_group  \
# 18761   African-American-Black       0     35-44          10 College
# 27582   African-American-Black       1    65-100          10 College
# 30911   African-American-Black       0     25-34          10 College
# 11128   African-American-Black       1     45-54  14 Master's Degree
# 683     African-American-Black       0     17-24          10 College
#
#       hours_per_week_group   fp
# 18761             Overtime  0.0
# 27582            Part-time  NaN
# 30911             Overtime  0.0
# 11128             Overtime  NaN
# 683               Overtime  0.0

# %%
fp_diver = DivergenceExplorer(df_val)
attributes = ['workclass', 'fnlwgt', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'native-country', 'age_group', 'edu_num_group', 'hours_per_week_group']
FP_fm = fp_diver.get_pattern_divergence(min_support=0.2, attributes=attributes,
                                        boolean_outcomes=['fp'])
FP_fm = FP_fm.sort_values(by="fp_div", ascending=False, ignore_index=True)
pd.set_option('display.max_colwidth', None)

FP_fm.head(5)
# Out:
#     support  \
# 0  0.238973
# 1  0.238973
# 2  0.238973
# 3  0.238973
# 4  0.259259
#
#                                                                                                                                                                               itemset  \
# 0             (native-country= African-American-Black, capital-gain=0.0, relationship= Husband, capital-loss=0.0, race= White, hours_per_week_group=Overtime, marital-status=Married)
# 1                                     (native-country= African-American-Black, capital-gain=0.0, relationship= Husband, capital-loss=0.0, race= White, hours_per_week_group=Overtime)
# 2                          (native-country= African-American-Black, capital-gain=0.0, relationship= Husband, capital-loss=0.0, race= White, hours_per_week_group=Overtime, sex= Male)
# 3  (native-country= African-American-Black, capital-gain=0.0, relationship= Husband, capital-loss=0.0, race= White, hours_per_week_group=Overtime, sex= Male, marital-status=Married)
# 4                    (native-country= African-American-Black, capital-gain=0.0, relationship= Husband, race= White, hours_per_week_group=Overtime, sex= Male, marital-status=Married)
#
#          fp    fp_div       fp_t  length  support_count
# 0  0.363021  0.223519  13.267867       7         1555.0
# 1  0.363021  0.223519  13.267867       6         1555.0
# 2  0.363021  0.223519  13.267867       7         1555.0
# 3  0.363021  0.223519  13.267867       8         1555.0
# 4  0.362069  0.222567  13.492036       7         1687.0

# %%
# Costruzione dei dati da FP_fm
fp_data = [
    (FP_fm['itemset'].iloc[0], FP_fm['fp_div'].loc[0]),
    (FP_fm['itemset'].iloc[1], FP_fm['fp_div'].loc[1]),
    (FP_fm['itemset'].iloc[2], FP_fm['fp_div'].loc[2]),
    (FP_fm['itemset'].iloc[3], FP_fm['fp_div'].loc[3]),
    (FP_fm['itemset'].iloc[4], FP_fm['fp_div'].loc[4]),
]

# Ordinamento per false positive divergence 
sorted_fp_data = sorted(fp_data, key=lambda x: x[1], reverse=True)


# Estrazione dei valori e degli itemset
sorted_fp_values = [fp_data[0][1]] + [item[1] for item in sorted_fp_data]
sorted_itemsets = [fp_data[0][0]] + [item[0] for item in sorted_fp_data]

# Rimozione parola 'frozenset'
#sorted_itemsets_labels = [', '.join(list(itemset)) for itemset in sorted_itemsets]
sorted_itemsets_labels = [', '.join(list(itemset)).replace('frozenset', '').replace(', ', '\n') for itemset in sorted_itemsets]


num_colors = len(sorted_fp_values)
colors = plt.cm.viridis(np.linspace(0, 0.8, num_colors)) 

plt.figure(figsize=(10, 10))  
bars = plt.barh(np.arange(len(sorted_itemsets_labels)), sorted_fp_values, color=colors)

# Etichette assi
plt.yticks(np.arange(len(sorted_itemsets_labels)), sorted_itemsets_labels)
plt.gca().set_yticklabels(sorted_itemsets_labels, rotation=0, ha='right', wrap=True)
plt.xlabel('False Positive Rate')
plt.title('Itemsets and Divergences')
for i, fp_value in enumerate(sorted_fp_values):
    plt.text(fp_value, i, f'{fp_value:.4f}', va='center', ha='left')
    
plt.tight_layout()  
plt.gca().invert_yaxis()  
plt.xlim(right=max(sorted_fp_values) * 1.2) 
plt.show()

# %% [markdown]
# Shapley values

# %%
#LOCAL
fp_details = DivergencePatternProcessor(FP_fm, 'fp')
pattern = fp_details.patterns['itemset'].iloc[0]
print(pattern)
sv = fp_details.shapley_value(pattern)
sv
# Out:
# frozenset({'native-country= African-American-Black', 'capital-gain=0.0', 'relationship= Husband', 'capital-loss=0.0', 'race= White', 'hours_per_week_group=Overtime', 'marital-status=Married'})
# {frozenset({'native-country= African-American-Black'}): 0.004775832420005285,
#  frozenset({'capital-gain=0.0'}): 0.006119687993121788,
#  frozenset({'relationship= Husband'}): 0.09509417424413898,
#  frozenset({'capital-loss=0.0'}): -0.0009073520568987604,
#  frozenset({'race= White'}): 0.008246873226206248,
#  frozenset({'hours_per_week_group=Overtime'}): 0.023022015672214798,
#  frozenset({'marital-status=Married'}): 0.08716826555352493}

# %%
# Sort Shapley values and corresponding frozenset keys
sorted_sv = sorted(sv.values(), reverse=True)
sorted_keys = sorted(sv, key=sv.get, reverse=True)

# Drop 'frozenset' and create readable labels
sorted_keys_labels = [', '.join(item) for item in sorted_keys]

colors = ['#B0E0E6', '#87CEEB', '#4682B4', '#7FFFD4', '#40E0D0', '#AFEEEE', '#E0FFFF', '#F0FFFF']

# Create the bar chart
plt.figure(figsize=(8, 4))
bars = plt.barh(np.arange(len(sorted_sv)), sorted_sv, color=colors[:len(sorted_sv)])
plt.yticks(np.arange(len(sorted_sv)), sorted_keys_labels)
plt.xlabel('Shapley Value')
plt.title("Shapley Values for the First Itemset")

# Add Shapley values to the bars
for i, value in enumerate(sorted_sv):
    plt.text(value, i, f'{value:.4f}', va='center', ha='left', color='black')

plt.gca().invert_yaxis()
plt.xlim(right=max(sorted_sv) * 1.1)  # Add some space to the right of bars
plt.tight_layout()
plt.show()

# %%
#GLOBAL
gsv = fp_details.global_shapley_value()
gsv
# Out:
# {frozenset({'relationship= Husband'}): 0.014273216692342598,
#  frozenset({'marital-status=Married'}): 0.013838032265541683,
#  frozenset({"education=Bachelor's Degree"}): 0.004151921148859003,
#  frozenset({'age_group=35-44'}): 0.00395591678735951,
#  frozenset({'sex= Male'}): 0.0034410351259817665,
#  frozenset({'occupation=Private-occ'}): 0.001883865201481749,
#  frozenset({'hours_per_week_group=Overtime'}): 0.004346146167317368,
#  frozenset({'occupation=Self-emp-occ'}): 0.0004931145506200831,
#  frozenset({'race= White'}): 0.001492712628419498,
#  frozenset({'capital-gain=0.0'}): 7.695328896883269e-05,
#  frozenset({'capital-loss=0.0'}): -0.0005762078297258482,
#  frozenset({'native-country= African-American-Black'}): -0.0002183266336312405,
#  frozenset({'edu_num_group=10 College'}): -0.0008147917577831229,
#  frozenset({'workclass=Private'}): -0.003502455610030817,
#  frozenset({'edu_num_group=9 High School Graduate'}): -0.0022568920264502664,
#  frozenset({'education=Non Graduated'}): -0.0035504027108090633,
#  frozenset({'age_group=25-34'}): -0.0025745981023389194,
#  frozenset({'relationship= Not-in-family'}): -0.004066007655479259,
#  frozenset({'sex= Female'}): -0.004687544919406155,
#  frozenset({'marital-status=Never-married'}): -0.007479857524530672}

# %%
#order gsv desc
sorted_gsv = sorted(gsv.items(), key=lambda x: x[1], reverse=True)

# extract itemset and Shapley values
itemsets = [' '.join(item) for item, value in sorted_gsv]
shapley_values = [value for item, value in sorted_gsv]

# Colours
colors = ['#FFC0CB', '#FF69B4', '#FF1493', '#FF7F50', '#FFA07A', '#FF6347', '#FF4500', '#FA8072', '#FFD700', '#FFA500', '#FF8C00', '#FFDAB9', '#FFE4B5', '#F08080']

# Graph of Shapley values
plt.figure(figsize=(8, 6))
bars = plt.barh(itemsets, shapley_values, color=colors[:len(itemsets)])
plt.xlabel('Shapley Value')
plt.title('Global Shapley Values')

# Add numbers
#for i, value in enumerate(shapley_values):
#    plt.text(value + 0.0005, i, format(value, '.4f'), va='center', ha='left', color='black')

plt.gca().invert_yaxis() 
plt.xlim(-0.020, 0.015)
plt.tight_layout()
plt.show()

# %% [markdown]
# BIAS MITIGATION: ADDING DATA: prendo dati dall'hold-out e li aggiungo al train set, questi dati matchano gli itemset trovati prima (i primi 4 )
#
# 1. prendo dati dall'holdout e li aggiungo train
# 2. riapplico encoding tutto
# 3. Decision tree nuovamente e vedo come sono cambiate le performance (ad es Accuracy e false positive rate)
#
# PROBLEMI GENERALI: QUANTITA DI DATI DA INSERIRE, COME SETTARE PARAMETRI NEL DIVEXPLORER

# %%
#dati da aggiungere: 
n_rows = 1000
filtered_df = df_holdout[
    (df_holdout['native-country'] == 'African-American-Black') |
    (df_holdout['capital-loss'] == 0.0)|
    (df_holdout['capital-gain'] == 0.0) |
    (df_holdout['relationship'] == 'Hursband') |
    (df_holdout['race'] == 'White') |
    (df_holdout['marital-status'] == 'Married')|
    (df_holdout['hours_per_week_group'] == 'Overtime') |
    (df_holdout['sex'] == 'Male')
    ]
top_n_rows = filtered_df.head(n_rows)
df_train_mitigated = pd.concat([df_train, top_n_rows], ignore_index=True)
print(f"Dim del dataframe holdout filtrato: ",filtered_df.shape)
print(f"Dim del dataframe di train con l'aggiunta di dati specifici : ", df_train_mitigated.shape)
# Out:
# Dim del dataframe holdout filtrato:  (6508, 15)
# Dim del dataframe di train con l'aggiunta di dati specifici :  (14014, 15)

# %%
filtered_df.head()
# Out:
#         workclass    fnlwgt        education marital-status      occupation  \
# 11774  Government  0.011455    Non Graduated        Married   Other-service
# 16690    Self-emp  0.102194    Non Graduated        Married     Private-occ
# 28196     Private  0.128838  Master's Degree        Married     Private-occ
# 10108     Private  0.013601    Non Graduated        Married   Other-service
# 16753     Private  0.106074    Non Graduated  Never-married  Government-occ
#
#       relationship    race      sex  capital-gain  capital-loss  \
# 11774         Wife   White   Female       0.00000           0.0
# 16690      Husband   White     Male       0.00000           0.0
# 28196      Husband   White     Male       0.04508           0.0
# 10108         Wife   White   Female       0.00000           0.0
# 16753    Own-child   White     Male       0.00000           0.0
#
#                 native-country  income age_group           edu_num_group  \
# 11774   African-American-Black       0     25-34         6-8 High School
# 16690   African-American-Black       1     35-44              10 College
# 28196                    Other       0     25-34  15 Professional Degree
# 10108   African-American-Black       0     25-34              10 College
# 16753   African-American-Black       0     25-34  9 High School Graduate
#
#       hours_per_week_group
# 11774             Overtime
# 16690             Overtime
# 28196             Overtime
# 10108             Overtime
# 16753             Overtime

# %%
#riapplico funzione di encoding, ma al posto di holdout, uso il df filtrato che devo usare per inserire dati 
df_train_enc_mit, df_test_enc_mit, df_filtered_enc, df_val_enc_mit = encoding_funct(df_train=df_train_mitigated, df_test=df_test, df_holdout=filtered_df, df_val=df_val)
#controllo divisione dataset
print(f"TRAIN SET ROWS: ", df_train_enc.shape[0])
print(f"TRAIN SET MITIGATED ROWS: ", df_train_enc_mit.shape[0]) #su 32536, il 40%  dovrebbe essere circa 13014
print(f"VALIDATION SET ROWS: ", df_val_enc_mit.shape[0]) #su 32536, il 20%  dovrebbe essere circa 6500
print(f"FILTERED DF ROWS: ", df_filtered_enc.shape[0])
print(f"TEST SET ROWS: ", df_test_enc_mit.shape[0])
# Out:
# TRAIN SET ROWS:  13014
# TRAIN SET MITIGATED ROWS:  14014
# VALIDATION SET ROWS:  6507
# FILTERED DF ROWS:  6508
# TEST SET ROWS:  6508

# %%
df_filtered_enc.head()
# Out:
#        workclass    fnlwgt  education  marital-status  occupation  \
# 11774          0  0.011455          3               1           1
# 16690          3  0.102194          3               1           2
# 28196          2  0.128838          2               1           2
# 10108          2  0.013601          3               1           1
# 16753          2  0.106074          3               2           0
#
#        relationship  race  sex  capital-gain  capital-loss  native-country  \
# 11774             5     4    0       0.00000           0.0               0
# 16690             0     4    1       0.00000           0.0               0
# 28196             0     4    1       0.04508           0.0               4
# 10108             5     4    0       0.00000           0.0               0
# 16753             3     4    1       0.00000           0.0               0
#
#        income  age_group  edu_num_group  hours_per_week_group
# 11774       0          1              9                     1
# 16690       1          2              1                     1
# 28196       0          1              5                     1
# 10108       0          1              1                     1
# 16753       0          1             10                     1

# %% [markdown]
# Train and test again, test set è come prima

# %%
X_train_mitigated = df_train_enc_mit.drop(columns = 'income', axis = 1)
y_train_mitigated = df_train_enc_mit['income']

dt.fit(X_train_mitigated, y_train_mitigated)
y_mitigated_pred = dt.predict(X_test)
cm_dt = confusion_matrix(y_test, y_mitigated_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=[False, True])
disp.plot()
plt.show()

# %%
print(classification_report(y_test, y_mitigated_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      4940
#            1       0.62      0.61      0.61      1568
#
#     accuracy                           0.81      6508
#    macro avg       0.75      0.74      0.74      6508
# weighted avg       0.81      0.81      0.81      6508

# %%
print(f"accuracy prima della mitigation: ", accuracy_score(y_test, y_pred) )
print(f"accuracy dopo la mitigazione: ", accuracy_score(y_test, y_mitigated_pred) )
# Out:
# accuracy prima della mitigation:  0.8056238475722188
# accuracy dopo la mitigazione:  0.8137676705593117

# %%
def calculate_fpr(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return fp / (fp + tn) if (fp + tn) > 0 else 0

print(f"false posoitive rate prima della mitigation",calculate_fpr(y_true=y_test, y_pred=y_pred))
print(f"false positive rate dopo la mitigazione",calculate_fpr(y_true=y_test, y_pred=y_mitigated_pred))
# Out:
# false posoitive rate prima della mitigation 0.13137651821862348
# false positive rate dopo la mitigazione 0.12004048582995952

# %% [markdown]
# L'accuracy aumenta un po' e il false possitive rate diminuisce un po'
#
# Riprovo supponendo di aggiungere righe finche l'accuracy non aumenta del 10%

# %%
#aggiungo 100 righe oer ogni iterazione
batch_size = 10

# Calcola l'accuratezza iniziale
def calculate_accuracy(df_train, df_test):

    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# Accuratezza iniziale
initial_accuracy = calculate_accuracy(df_train_enc, df_test_enc)
print(f"Accuratezza iniziale: {initial_accuracy:}")

while True:
    batch = df_filtered_enc.head(batch_size)
    df_train_mitigated = pd.concat([df_train_enc, batch], ignore_index=True)
    df_filtered_enc = df_filtered_enc.iloc[batch_size:].reset_index(drop=True)
    new_accuracy = calculate_accuracy(df_train_mitigated, df_test_enc)
    print(f"Nuova accuratezza: {new_accuracy:}")

    if new_accuracy >= initial_accuracy * 1.10:
        print("L'accuratezza è aumentata del 10% almeno.")
        break

    if len(df_filtered_enc) < batch_size:
        print("Target non raggiungibile")
        break
# Out:
# Accuratezza iniziale: 0.8080823601720959
# Nuova accuratezza: 0.8065457897971727
# Nuova accuratezza: 0.8042409342347879
# Nuova accuratezza: 0.8085433312845728
# Nuova accuratezza: 0.8048555623847572
# Nuova accuratezza: 0.8086969883220652
# Nuova accuratezza: 0.8080823601720959
# Nuova accuratezza: 0.8059311616472035
# Nuova accuratezza: 0.8094652735095267
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8086969883220652
# Nuova accuratezza: 0.8085433312845728
# Nuova accuratezza: 0.8102335586969883
# Nuova accuratezza: 0.8102335586969883
# Nuova accuratezza: 0.8100799016594961
# Nuova accuratezza: 0.8054701905347265
# Nuova accuratezza: 0.8083896742470805
# Nuova accuratezza: 0.8040872771972957
# Nuova accuratezza: 0.8042409342347879
# Nuova accuratezza: 0.8076213890596189
# Nuova accuratezza: 0.806699446834665
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8076213890596189
# Nuova accuratezza: 0.807160417947142
# Nuova accuratezza: 0.8074677320221266
# Nuova accuratezza: 0.8054701905347265
# Nuova accuratezza: 0.8059311616472035
# Nuova accuratezza: 0.8047019053472649
# Nuova accuratezza: 0.8099262446220037
# Nuova accuratezza: 0.8059311616472035
# Nuova accuratezza: 0.8057775046097111
# Nuova accuratezza: 0.806699446834665
# Nuova accuratezza: 0.8082360172095882
# Nuova accuratezza: 0.8056238475722188
# Nuova accuratezza: 0.8054701905347265
# Nuova accuratezza: 0.807160417947142
# Nuova accuratezza: 0.8054701905347265
# Nuova accuratezza: 0.8059311616472035
# Nuova accuratezza: 0.8088506453595574
# Nuova accuratezza: 0.8083896742470805
# Nuova accuratezza: 0.8060848186846957
# Nuova accuratezza: 0.8042409342347879
# Nuova accuratezza: 0.8090043023970498
# Nuova accuratezza: 0.8116164720344192
# Nuova accuratezza: 0.8048555623847572
# Nuova accuratezza: 0.8053165334972342
# Nuova accuratezza: 0.8079287031346035
# Nuova accuratezza: 0.8060848186846957
# Nuova accuratezza: 0.8063921327596804
# Nuova accuratezza: 0.8096189305470191
# Nuova accuratezza: 0.8060848186846957
# Nuova accuratezza: 0.8080823601720959
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8085433312845728
# Nuova accuratezza: 0.8062384757221881
# Nuova accuratezza: 0.8074677320221266
# Nuova accuratezza: 0.807160417947142
# Nuova accuratezza: 0.8074677320221266
# Nuova accuratezza: 0.8079287031346035
# Nuova accuratezza: 0.8062384757221881
# Nuova accuratezza: 0.8048555623847572
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8060848186846957
# Nuova accuratezza: 0.807160417947142
# Nuova accuratezza: 0.8045482483097726
# Nuova accuratezza: 0.8076213890596189
# Nuova accuratezza: 0.8086969883220652
# Nuova accuratezza: 0.809157959434542
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8085433312845728
# Nuova accuratezza: 0.8093116164720344
# Nuova accuratezza: 0.8070067609096496
# Nuova accuratezza: 0.8073140749846343
# Nuova accuratezza: 0.8077750460971113
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8070067609096496
# Nuova accuratezza: 0.8080823601720959
# Nuova accuratezza: 0.8102335586969883
# Nuova accuratezza: 0.8050092194222496
# Nuova accuratezza: 0.8060848186846957
# Nuova accuratezza: 0.8080823601720959
# Nuova accuratezza: 0.8073140749846343
# Nuova accuratezza: 0.8080823601720959
# Nuova accuratezza: 0.810540872771973
# Nuova accuratezza: 0.8083896742470805
# Nuova accuratezza: 0.8054701905347265
# Nuova accuratezza: 0.8068531038721574
# Nuova accuratezza: 0.8074677320221266
# Nuova accuratezza: 0.8079287031346035
# Nuova accuratezza: 0.8096189305470191
# Nuova accuratezza: 0.8050092194222496
# Nuova accuratezza: 0.8076213890596189
# Nuova accuratezza: 0.8057775046097111
# Nuova accuratezza: 0.8053165334972342
# Nuova accuratezza: 0.8051628764597418
# Nuova accuratezza: 0.8065457897971727
# Nuova accuratezza: 0.